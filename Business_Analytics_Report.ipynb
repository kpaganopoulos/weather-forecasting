# %% [markdown]
# # Business Analytics Report

# %% [markdown]
# First, we load the necessary libraries:

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %% [markdown]
# Then we load the data set.

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#    year  month  mean_temp  mean_max_temp  mean_min_temp  max_temp  min_temp  \
# 0  2001      1       -2.7            0.0           -5.3       7.4     -10.5
# 1  2001      2       -2.5            0.2           -5.0       8.3      -9.9
# 2  2001      3        2.1            5.6           -1.3      13.7      -7.7
# 3  2001      4        9.1           14.6            4.2      22.9      -0.3
# 4  2001      5       13.7           18.4            9.2      29.1       3.0
#
#    precipitation  highest_daily_prec  mean_wind_speed  highest_wind_gust  \
# 0          186.0                17.5             16.2               83.5
# 1          122.5                13.5             17.2              114.1
# 2           66.5                11.0             15.5               97.2
# 3           31.5                15.0             15.5              107.6
# 4           81.5                24.5             13.3               79.9
#
# ...

# %%
data2 = data.drop(['year','month'], axis=1)

# %%
data2.describe()
# Out:
#         mean_temp  mean_max_temp  mean_min_temp    max_temp    min_temp  \
# count  216.000000     216.000000     216.000000  216.000000  216.000000
# mean    10.675926      14.825463       7.112500   22.119907    2.105093
# std      8.615188       9.187871       8.373934    9.091791    8.174277
# min     -2.700000      -0.200000      -5.300000    3.400000  -10.900000
# 25%      2.075000       5.825000      -1.200000   14.075000   -5.525000
# 50%     11.150000      16.400000       6.850000   23.950000    0.850000
# 75%     18.425000      23.125000      14.800000   30.100000    9.225000
# max     26.000000      30.600000      22.200000   36.600000   18.000000
#
#        precipitation  highest_daily_prec  mean_wind_speed  highest_wind_gust  \
# count     216.000000          216.000000       216.000000         216.000000
# mean      117.946759           31.150463        13.342130          80.656019
# std        62.382546           25.928377         2.095562          15.908107
# ...

# %%
corr_matrix = data[['mean_temp','precipitation','mean_wind_speed','mean_rel_humidity','mean_atm_pressure']].corr()
plt.figure(figsize = (10, 10))
g = sns.heatmap(corr_matrix, annot=True, square=True, center = 0, vmin = -1, vmax = 1, fmt='.3g', cmap= 'coolwarm', linewidths=3, linecolor='black', cbar_kws= {'orientation': 'horizontal'})
g.set_xticklabels(g.get_xticklabels(), rotation=40, horizontalalignment='center')
g.set_yticklabels(g.get_yticklabels(), rotation=0, horizontalalignment='right')
bottom, top = g.get_ylim()
g.set_ylim(bottom + 0.5, top - 0.5)
g.set_title('Aomori city Meteorological Parameters - Heatmap from Correlation Matrix')
plt.show()
